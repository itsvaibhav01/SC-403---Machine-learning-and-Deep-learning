# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('classifier_actuator.csv',header=None)

# %%
from sklearn.model_selection import train_test_split 
X=df[[0,1]].values
y=df[2].values
print(len(X[:,1]),len(y))
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1, test_size=0.3)
# Out:
# 500 500

# %%
plt.scatter(X[:,0],X[:,1], c=y, s=5, cmap = 'cool')

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.neighbors import KNeighborsClassifier

# %%
k_list = [1,2,3,4,5,8,10,20]
for i in range(len(k_list)):
    num_neighbors = k_list[i]
    knn = KNeighborsClassifier(n_neighbors= num_neighbors)
    knn.fit(X,y)
    knn_predictions = knn.predict(X_test)
    accuracy = knn.score(X_test, y_test)   
    cm = confusion_matrix(y_test, knn_predictions)
    knn_new = knn.predict(X)
    plt.scatter(X[:,0],X[:,1], c=knn_new , s=5, cmap = 'cool')
    plt.show()
    print(k_list[i])
    print(accuracy)
    print(cm)
    print("-----------------------------------------------------------------")
# Out:
# 1
# 1.0
# [[116   0]
#  [  0  34]]
# -----------------------------------------------------------------
# 2
# 0.8333333333333334
# [[116   0]
#  [ 25   9]]
# -----------------------------------------------------------------
# 3
# 0.8266666666666667
# [[112   4]
#  [ 22  12]]
# -----------------------------------------------------------------
# 4
# 0.7733333333333333
# [[114   2]
#  [ 32   2]]
# -----------------------------------------------------------------
# 5
# 0.8133333333333334
# [[111   5]
#  [ 23  11]]
# -----------------------------------------------------------------
# 8
# 0.7933333333333333
# [[115   1]
#  [ 30   4]]
# -----------------------------------------------------------------
# 10
# 0.78
# [[116   0]
#  [ 33   1]]
# -----------------------------------------------------------------
# 20
# 0.7733333333333333
# [[116   0]
#  [ 34   0]]
# -----------------------------------------------------------------
